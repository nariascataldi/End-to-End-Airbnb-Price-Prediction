# %% [markdown]
# # Importing Libraries

# %%
pip install catboost
# Out:
# Requirement already satisfied: catboost in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (1.2.8)
# Requirement already satisfied: graphviz in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from catboost) (3.10.8)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from catboost) (2.4.1)
# Requirement already satisfied: pandas>=0.24 in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from catboost) (2.3.3)
# Requirement already satisfied: scipy in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from catboost) (1.17.0)
# Requirement already satisfied: plotly in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from catboost) (6.5.1)
# Requirement already satisfied: six in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from pandas>=0.24->catboost) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from matplotlib->catboost) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from matplotlib->catboost) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from matplotlib->catboost) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from matplotlib->catboost) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from matplotlib->catboost) (3.3.1)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/nestorariascataldi/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages (from plotly->catboost) (2.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import  LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import Pipeline
from catboost import CatBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
#from xgboost import XGBRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Importing Data

# %%
df = pd.read_csv("Data/Airbnb_Data.csv")

# %% [markdown]
# # Data Exploration

# %%
df
# Out:
#              id  log_price property_type        room_type  \
# 0       6901257   5.010635     Apartment  Entire home/apt
# 1       6304928   5.129899     Apartment  Entire home/apt
# 2       7919400   4.976734     Apartment  Entire home/apt
# 3      13418779   6.620073         House  Entire home/apt
# 4       3808709   4.744932     Apartment  Entire home/apt
# ...         ...        ...           ...              ...
# 74106  14549287   4.605170     Apartment     Private room
# 74107  13281809   5.043425     Apartment  Entire home/apt
# 74108  18688039   5.220356     Apartment  Entire home/apt
# 74109  17045948   5.273000     Apartment  Entire home/apt
# 74110   3534845   4.852030          Boat  Entire home/apt
#
#                                                amenities  accommodates  \
# 0      {"Wireless Internet","Air conditioning",Kitche...             3
# 1      {"Wireless Internet","Air conditioning",Kitche...             7
# 2      {TV,"Cable TV","Wireless Internet","Air condit...             5
# 3      {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4
# 4      {TV,Internet,"Wireless Internet","Air conditio...             2
# ...                                                  ...           ...
# 74106                                                 {}             1
# 74107  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4
# 74108  {TV,Internet,"Wireless Internet","Air conditio...             5
# 74109  {TV,"Wireless Internet","Air conditioning",Kit...             2
# 74110  {TV,Internet,"Wireless Internet",Kitchen,"Free...             4
#
#        bathrooms  bed_type cancellation_policy  cleaning_fee  ...   latitude  \
# 0            1.0  Real Bed              strict          True  ...  40.696524
# 1            1.0  Real Bed              strict          True  ...  40.766115
# 2            1.0  Real Bed            moderate          True  ...  40.808110
# 3            1.0  Real Bed            flexible          True  ...  37.772004
# 4            1.0  Real Bed            moderate          True  ...  38.925627
# ...          ...       ...                 ...           ...  ...        ...
# 74106        1.0  Real Bed            flexible         False  ...  40.709025
# 74107        2.0  Real Bed            moderate          True  ...  33.871549
# 74108        1.0  Real Bed            moderate          True  ...  40.706749
# 74109        1.0  Real Bed              strict          True  ...  40.738535
# 74110        1.0  Real Bed            moderate         False  ...  33.761096
#
#         longitude                                        name  \
# 0      -73.991617              Beautiful brownstone 1-bedroom
# 1      -73.989040    Superb 3BR Apt Located Near Times Square
# 2      -73.943756                            The Garden Oasis
# 3     -122.431619          Beautiful Flat in the Heart of SF!
# 4      -77.034596                  Great studio in midtown DC
# ...           ...                                         ...
# 74106  -73.939405                           one room bushwick
# 74107 -118.396053                Spacious Hermosa 2 BR on PCH
# 74108  -73.942377  Modern 2 Bedroom Apartment in Williamsburg
# 74109  -74.000157        Designer's Apartment in HEART of NYC
# 74110 -118.192409              Cozy Boat at Shoreline Village
#
#           neighbourhood number_of_reviews review_scores_rating  \
# 0      Brooklyn Heights                 2                100.0
# 1        Hell's Kitchen                 6                 93.0
# 2                Harlem                10                 92.0
# 3          Lower Haight                 0                  NaN
# 4      Columbia Heights                 4                 40.0
# ...                 ...               ...                  ...
# 74106      Williamsburg                 0                  NaN
# 74107     Hermosa Beach                16                 93.0
# 74108      Williamsburg                43                 94.0
# 74109      West Village                 0                  NaN
# 74110        Long Beach               205                 96.0
#
#                                            thumbnail_url  zipcode bedrooms  \
# 0      https://a0.muscache.com/im/pictures/6d7cbbf7-c...    11201      1.0
# 1      https://a0.muscache.com/im/pictures/348a55fe-4...    10019      3.0
# 2      https://a0.muscache.com/im/pictures/6fae5362-9...    10027      1.0
# 3      https://a0.muscache.com/im/pictures/72208dad-9...  94117.0      2.0
# 4                                                    NaN    20009      0.0
# ...                                                  ...      ...      ...
# 74106  https://a0.muscache.com/im/pictures/55162426/6...  11206.0      1.0
# 74107  https://a0.muscache.com/im/pictures/2b86560b-a...    90254      2.0
# 74108  https://a0.muscache.com/im/pictures/7fbe448c-5...  11206.0      2.0
# 74109  https://a0.muscache.com/im/pictures/b3971b63-0...    10011      0.0
# 74110  https://a0.muscache.com/im/pictures/22968537/d...    90802      1.0
#
#        beds
# 0       1.0
# 1       3.0
# 2       3.0
# 3       2.0
# 4       1.0
# ...     ...
# 74106   1.0
# 74107   4.0
# 74108   2.0
# 74109   2.0
# 74110   2.0
#
# [74111 rows x 29 columns]

# %%
df.shape
# Out:
# (74111, 29)

# %%
df.columns
# Out:
# Index(['id', 'log_price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'description', 'first_review',
#        'host_has_profile_pic', 'host_identity_verified', 'host_response_rate',
#        'host_since', 'instant_bookable', 'last_review', 'latitude',
#        'longitude', 'name', 'neighbourhood', 'number_of_reviews',
#        'review_scores_rating', 'thumbnail_url', 'zipcode', 'bedrooms', 'beds'],
#       dtype='object')

# %%
df.describe()
# Out:
#                  id     log_price  accommodates     bathrooms      latitude  \
# count  7.411100e+04  74111.000000  74111.000000  73911.000000  74111.000000
# mean   1.126662e+07      4.782069      3.155146      1.235263     38.445958
# std    6.081735e+06      0.717394      2.153589      0.582044      3.080167
# min    3.440000e+02      0.000000      1.000000      0.000000     33.338905
# 25%    6.261964e+06      4.317488      2.000000      1.000000     34.127908
# 50%    1.225415e+07      4.709530      2.000000      1.000000     40.662138
# 75%    1.640226e+07      5.220356      4.000000      1.000000     40.746096
# max    2.123090e+07      7.600402     16.000000      8.000000     42.390437
#
#           longitude  number_of_reviews  review_scores_rating      bedrooms  \
# count  74111.000000       74111.000000          57389.000000  74020.000000
# mean     -92.397525          20.900568             94.067365      1.265793
# std       21.705322          37.828641              7.836556      0.852143
# min     -122.511500           0.000000             20.000000      0.000000
# 25%     -118.342374           1.000000             92.000000      1.000000
# 50%      -76.996965           6.000000             96.000000      1.000000
# 75%      -73.954660          23.000000            100.000000      1.000000
# max      -70.985047         605.000000            100.000000     10.000000
#
#                beds
# count  73980.000000
# mean       1.710868
# std        1.254142
# min        0.000000
# 25%        1.000000
# 50%        1.000000
# 75%        2.000000
# max       18.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   id                      74111 non-null  int64
#  1   log_price               74111 non-null  float64
#  2   property_type           74111 non-null  object
#  3   room_type               74111 non-null  object
#  4   amenities               74111 non-null  object
#  5   accommodates            74111 non-null  int64
#  6   bathrooms               73911 non-null  float64
#  7   bed_type                74111 non-null  object
#  8   cancellation_policy     74111 non-null  object
#  9   cleaning_fee            74111 non-null  bool
#  10  city                    74111 non-null  object
#  11  description             74111 non-null  object
#  12  first_review            58247 non-null  object
#  13  host_has_profile_pic    73923 non-null  object
#  14  host_identity_verified  73923 non-null  object
#  15  host_response_rate      55812 non-null  object
#  16  host_since              73923 non-null  object
#  17  instant_bookable        74111 non-null  object
#  18  last_review             58284 non-null  object
#  19  latitude                74111 non-null  float64
#  20  longitude               74111 non-null  float64
#  21  name                    74111 non-null  object
#  22  neighbourhood           67239 non-null  object
#  23  number_of_reviews       74111 non-null  int64
#  24  review_scores_rating    57389 non-null  float64
#  25  thumbnail_url           65895 non-null  object
#  26  zipcode                 73145 non-null  object
#  27  bedrooms                74020 non-null  float64
#  28  beds                    73980 non-null  float64
# dtypes: bool(1), float64(7), int64(3), object(18)
# memory usage: 15.9+ MB

# %%
df.dtypes
# Out:
# id                          int64
# log_price                 float64
# property_type              object
# room_type                  object
# amenities                  object
# accommodates                int64
# bathrooms                 float64
# bed_type                   object
# cancellation_policy        object
# cleaning_fee                 bool
# city                       object
# description                object
# first_review               object
# host_has_profile_pic       object
# host_identity_verified     object
# host_response_rate         object
# host_since                 object
# instant_bookable           object
# last_review                object
# latitude                  float64
# longitude                 float64
# name                       object
# neighbourhood              object
# number_of_reviews           int64
# review_scores_rating      float64
# thumbnail_url              object
# zipcode                    object
# bedrooms                  float64
# beds                      float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# id                            0
# log_price                     0
# property_type                 0
# room_type                     0
# amenities                     0
# accommodates                  0
# bathrooms                   200
# bed_type                      0
# cancellation_policy           0
# cleaning_fee                  0
# city                          0
# description                   0
# first_review              15864
# host_has_profile_pic        188
# host_identity_verified      188
# host_response_rate        18299
# host_since                  188
# instant_bookable              0
# last_review               15827
# latitude                      0
# longitude                     0
# name                          0
# neighbourhood              6872
# number_of_reviews             0
# review_scores_rating      16722
# thumbnail_url              8216
# zipcode                     966
# bedrooms                     91
# beds                        131
# dtype: int64

# %%
df["zipcode"].unique
# Out:
# <bound method Series.unique of 0          11201
# 1          10019
# 2          10027
# 3        94117.0
# 4          20009
#           ...
# 74106    11206.0
# 74107      90254
# 74108    11206.0
# 74109      10011
# 74110      90802
# Name: zipcode, Length: 74111, dtype: object>

# %%
index= ["host_response_rate","property_type", "room_type","accommodates","bathrooms","bed_type", "cancellation_policy", "cleaning_fee",
       "city","instant_bookable", "beds", "bedrooms", "neighbourhood","first_review", "last_review","zipcode",
       "name","host_since","thumbnail_url", "latitude", "longitude", 
        "host_has_profile_pic", "host_identity_verified"]

for i in index:
    
    print(df[i].value_counts(), "\n")
    print("---------------------------------------------------------------")
# Out:
# host_response_rate
# 100%    43254
# 90%      2277
# 80%      1113
# 0%        883
# 50%       611
#         ...
# 39%         1
# 15%         1
# 31%         1
# 21%         1
# 6%          1
# Name: count, Length: 80, dtype: int64
#
# ---------------------------------------------------------------
# property_type
# Apartment             49003
# House                 16511
# Condominium            2658
# Townhouse              1692
# Loft                   1244
# Other                   607
# Guesthouse              498
# Bed & Breakfast         462
# Bungalow                366
# Villa                   179
# Dorm                    142
# Guest suite             123
# Camper/RV                94
# Timeshare                77
# Cabin                    72
# In-law                   71
# Hostel                   70
# Boutique hotel           69
# Boat                     65
# Serviced apartment       21
# Tent                     18
# Castle                   13
# Vacation home            11
# Yurt                      9
# Hut                       8
# Treehouse                 7
# Chalet                    6
# Earth House               4
# Tipi                      3
# Train                     2
# Cave                      2
# Casa particular           1
# Parking Space             1
# Lighthouse                1
# Island                    1
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# room_type
# Entire home/apt    41310
# Private room       30638
# Shared room         2163
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# accommodates
# 2     31854
# 4     12066
# 1      9434
# 3      7794
# 6      4969
# 5      3444
# 8      1795
# 7       946
# 10      701
# 16      301
# 9       270
# 12      264
# 14      104
# 11       79
# 15       54
# 13       36
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# bathrooms
# 1.0    58099
# 2.0     7936
# 1.5     3801
# 2.5     1567
# 3.0     1066
# 3.5      429
# 4.0      286
# 0.5      209
# 0.0      198
# 4.5      116
# 5.0       72
# 8.0       41
# 5.5       39
# 6.0       24
# 6.5       12
# 7.0       10
# 7.5        6
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# bed_type
# Real Bed         72028
# Futon              753
# Pull-out Sofa      585
# Airbed             477
# Couch              268
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# cancellation_policy
# strict             32374
# flexible           22545
# moderate           19063
# super_strict_30      112
# super_strict_60       17
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# cleaning_fee
# True     54403
# False    19708
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# city
# NYC        32349
# LA         22453
# SF          6434
# DC          5688
# Chicago     3719
# Boston      3468
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# instant_bookable
# f    54660
# t    19451
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# beds
# 1.0     45144
# 2.0     16704
# 3.0      6442
# 4.0      3065
# 5.0      1287
# 6.0       661
# 7.0       216
# 8.0       186
# 10.0       88
# 9.0        72
# 16.0       38
# 12.0       29
# 11.0       23
# 13.0       10
# 15.0        6
# 14.0        4
# 0.0         4
# 18.0        1
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# bedrooms
# 1.0     49784
# 2.0     11351
# 0.0      6715
# 3.0      4309
# 4.0      1330
# 5.0       355
# 6.0       106
# 7.0        38
# 8.0        14
# 10.0       10
# 9.0         8
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# neighbourhood
# Williamsburg          2862
# Bedford-Stuyvesant    2166
# Bushwick              1601
# Upper West Side       1396
# Mid-Wilshire          1392
#                       ...
# Mill Basin               1
# Mt. Vernon Square        1
# Chevy Chase, MD          1
# Clearing                 1
# Grant City               1
# Name: count, Length: 619, dtype: int64
#
# ---------------------------------------------------------------
# first_review
# 2017-01-01    293
# 2017-01-22    249
# 2016-01-02    221
# 2017-01-02    211
# 2017-09-04    193
#              ...
# 2012-12-09      1
# 2012-04-20      1
# 2010-11-29      1
# 2011-03-28      1
# 2010-12-01      1
# Name: count, Length: 2554, dtype: int64
#
# ---------------------------------------------------------------
# last_review
# 2017-04-30    1344
# 2017-09-24    1278
# 2017-09-17    1215
# 2017-04-23    1025
# 2017-09-18     832
#               ...
# 2013-12-11       1
# 2014-06-19       1
# 2013-10-26       1
# 2011-03-28       1
# 2013-12-28       1
# Name: count, Length: 1371, dtype: int64
#
# ---------------------------------------------------------------
# zipcode
# 11211.0       1368
# 90291         1274
# 11221         1188
# 94110          988
# 90046          967
#               ...
# 10025.0          1
# 91606-1412       1
# 20781            1
# 15074            1
# 10012.0          1
# Name: count, Length: 769, dtype: int64
#
# ---------------------------------------------------------------
# name
# Bunk bed in the Treat Street Clubhouse           8
# Your home away from home                         7
# East Village Studio                              7
# Cozy Private Room                                6
# Location, Location, Location                     6
#                                                 ..
# Charming studio apartment in Adams Morgan.       1
# Studio City cozy studio w/ parking               1
# SPACIOUS UPPER HAIGHT HOME IN THE HEART OF SF    1
# Downtown LA Luxury Apartment 2                   1
# Cozy Boat at Shoreline Village                   1
# Name: count, Length: 73359, dtype: int64
#
# ---------------------------------------------------------------
# host_since
# 2015-03-30    246
# 2014-02-14    173
# 2015-05-18     83
# 2016-09-16     83
# 2015-07-06     82
#              ...
# 2009-04-08      1
# 2009-11-22      1
# 2010-02-28      1
# 2009-05-11      1
# 2009-08-23      1
# Name: count, Length: 3087, dtype: int64
#
# ---------------------------------------------------------------
# thumbnail_url
# https://a0.muscache.com/im/pictures/70087089/bc66229a_original.jpg?aki_policy=small              3
# https://a0.muscache.com/im/pictures/23033013/54d62516_original.jpg?aki_policy=small              2
# https://a0.muscache.com/im/pictures/104667326/a7a2b145_original.jpg?aki_policy=small             2
# https://a0.muscache.com/im/pictures/95059281/d8bfc436_original.jpg?aki_policy=small              2
# https://a0.muscache.com/im/pictures/4491e5c5-33f6-4704-9887-76a059f86fda.jpg?aki_policy=small    2
#                                                                                                 ..
# https://a0.muscache.com/im/pictures/111150220/7099e1de_original.jpg?aki_policy=small             1
# https://a0.muscache.com/im/pictures/bfc6695c-93f9-4a90-a6d8-9f6c038fff28.jpg?aki_policy=small    1
# https://a0.muscache.com/im/pictures/99319739/70c4beaf_original.jpg?aki_policy=small              1
# https://a0.muscache.com/im/pictures/3897544/bed318ce_original.jpg?aki_policy=small               1
# https://a0.muscache.com/im/pictures/22968537/da0156bc_original.jpg?aki_policy=small              1
# Name: count, Length: 65883, dtype: int64
#
# ---------------------------------------------------------------
# latitude
# 40.696524    1
# 40.711018    1
# 40.857493    1
# 38.896043    1
# 33.972140    1
#             ..
# 40.710462    1
# 40.764285    1
# 41.890929    1
# 42.013862    1
# 33.761096    1
# Name: count, Length: 74111, dtype: int64
#
# ---------------------------------------------------------------
# longitude
# -73.991617     1
# -73.953315     1
# -73.932585     1
# -76.976165     1
# -118.451806    1
#               ..
# -73.960735     1
# -73.980426     1
# -87.619302     1
# -87.681281     1
# -118.192409    1
# Name: count, Length: 74111, dtype: int64
#
# ---------------------------------------------------------------
# host_has_profile_pic
# t    73697
# f      226
# Name: count, dtype: int64
#
# ---------------------------------------------------------------
# host_identity_verified
# t    49748
# f    24175
# Name: count, dtype: int64
#
# ---------------------------------------------------------------

# %% [markdown]
# # Data Pre-processing

# %% [markdown]
# # Handling Missing Values

# %%
for column in df.columns:
    
    if df[column].isnull().sum() != 0:
        
        print("========================================")
        print("\n{} :- {},  dtypes : {}".format(column,df[column].isnull().sum(),df[column].dtypes))
# Out:
# ========================================
#
# bathrooms :- 200,  dtypes : float64
# ========================================
#
# first_review :- 15864,  dtypes : object
# ========================================
#
# host_has_profile_pic :- 188,  dtypes : object
# ========================================
#
# host_identity_verified :- 188,  dtypes : object
# ========================================
#
# host_response_rate :- 18299,  dtypes : object
# ========================================
#
# host_since :- 188,  dtypes : object
# ========================================
#
# last_review :- 15827,  dtypes : object
# ========================================
#
# neighbourhood :- 6872,  dtypes : object
# ========================================
#
# review_scores_rating :- 16722,  dtypes : float64
# ========================================
#
# thumbnail_url :- 8216,  dtypes : object
# ========================================
#
# zipcode :- 966,  dtypes : object
# ========================================
#
# bedrooms :- 91,  dtypes : float64
# ========================================
#
# beds :- 131,  dtypes : float64

# %% [markdown]
# Last Review

# %%
df.last_review.fillna(method="ffill",inplace=True)

# %% [markdown]
# First Review

# %%
df.first_review.fillna(method="ffill",inplace=True)

# %% [markdown]
# Host Since

# %%
df.host_since.fillna(method="ffill",inplace=True)

# %% [markdown]
# Bathrooms

# %%
sns.distplot(df["bathrooms"])
# Out:
# <Axes: xlabel='bathrooms', ylabel='Density'>

# %%
df["bathrooms"] = df['bathrooms'].fillna(round(df["bathrooms"].median()))

# %% [markdown]
# Review_Scores_Rating

# %%
sns.distplot(df["review_scores_rating"])
# Out:
# <Axes: xlabel='review_scores_rating', ylabel='Density'>

# %%
df["review_scores_rating"] = df["review_scores_rating"].fillna(0)

# %% [markdown]
# Bedrooms

# %%
sns.distplot(df["bedrooms"])
plt.show()

# %%
df["bedrooms"] = df['bedrooms'].fillna((df["bathrooms"].median()))

# %% [markdown]
# Beds

# %%
sns.distplot(df["beds"])
plt.show()

# %%
df["beds"] = df["beds"].fillna((df["bathrooms"].median()))

# %% [markdown]
# Amenties

# %%
amenities_count = []
for i in df["amenities"]:
    amenities_count.append(len(i))
    
df["amenities"] = amenities_count

# %% [markdown]
# # Data Visualisation

# %%
# Function to plot catplot graphs
def plot_catplot(h,v,he,a):
    sns.set(font_scale=1.5)
    sns.catplot(x=h,kind=v,data=df,height=he, aspect = a)
    
# Function to plot catplot graphs
def plot_piechart(h):
    sns.set(font_scale=1.5)
    fig = plt.figure(figsize=(5,5))
    ax = fig.add_axes([0,0,1,1])
    ax.axis('equal')
    langs = list(df[h].unique())
    students =list(df[h].value_counts())
    ax.pie(students, labels = langs,autopct='%1.2f%%')
    plt.show()

# %%
plt.figure(figsize = (10, 8))
sns.distplot(df["log_price"])
plt.title('Price distribution')
plt.show()

# %%
plot_catplot("room_type", "count", 5, 2)

# %%
plot_piechart("room_type")

# %%
plot_catplot("city","count", 5, 2)

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
langs = list(df.city.unique())
students =list(df.city.value_counts())
ax.pie(students, labels = langs,autopct='%1.2f%%')
plt.show()

# %%
data = df.neighbourhood.value_counts()[:15]
plt.figure(figsize=(22,22))
x = list(data.index)
y = list(data.values)
x.reverse()
y.reverse()

plt.title("Most popular Neighbourhood")
plt.ylabel("Neighbourhood Area")
plt.xlabel("Number of guest who host in this area")

plt.barh(x,y)
plt.show()

# %%
plot_catplot("cancellation_policy","count",10, 2)

# %%
plot_catplot("cleaning_fee","count",6,2)

# %%
def plot_violinplot(h,v):
    plt.figure(figsize=(15,8))
    sns.set(font_scale=1.5)
    sns.violinplot(data=df, x=h, y=v, palette='GnBu_d')
    plt.title('Density and distribution of prices ', fontsize=15)
    plt.xlabel(h)
    plt.ylabel(v)

# %%
plot_violinplot("city","log_price")

# %%
plot_violinplot("room_type","log_price")

# %%
plot_violinplot("cancellation_policy","log_price")

# %%
plot_violinplot("bed_type","log_price")

# %%
plot_catplot("bed_type","count",8, 2)

# %%
categorical_col = []
numerical_col = []
for column in df.columns:
    
    if df[column].dtypes != "float64" and df[column].dtypes != "int64":
        categorical_col.append(column)
    else:
        numerical_col.append(column)

# %%
numerical_col
# Out:
# ['id',
#  'log_price',
#  'amenities',
#  'accommodates',
#  'bathrooms',
#  'latitude',
#  'longitude',
#  'number_of_reviews',
#  'review_scores_rating',
#  'bedrooms',
#  'beds']

# %%
categorical_col
# Out:
# ['property_type',
#  'room_type',
#  'bed_type',
#  'cancellation_policy',
#  'cleaning_fee',
#  'city',
#  'description',
#  'first_review',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'host_response_rate',
#  'host_since',
#  'instant_bookable',
#  'last_review',
#  'name',
#  'neighbourhood',
#  'thumbnail_url',
#  'zipcode']

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
for col in categorical_col:
    df[col] = le.fit_transform(df[col])

# %%
pd.set_option("display.max_columns",None)
df
# Out:
#              id  log_price  property_type  room_type  amenities  accommodates  \
# 0       6901257   5.010635              0          0        152             3
# 1       6304928   5.129899              0          0        218             7
# 2       7919400   4.976734              0          0        311             5
# 3      13418779   6.620073             17          0        210             4
# 4       3808709   4.744932              0          0        174             2
# ...         ...        ...            ...        ...        ...           ...
# 74106  14549287   4.605170              0          1          2             1
# 74107  13281809   5.043425              0          0        224             4
# 74108  18688039   5.220356              0          0        402             5
# 74109  17045948   5.273000              0          0        189             2
# 74110   3534845   4.852030              2          0        279             4
#
#        bathrooms  bed_type  cancellation_policy  cleaning_fee  city  \
# 0            1.0         4                    2             1     4
# 1            1.0         4                    2             1     4
# 2            1.0         4                    1             1     4
# 3            1.0         4                    0             1     5
# 4            1.0         4                    1             1     2
# ...          ...       ...                  ...           ...   ...
# 74106        1.0         4                    0             0     4
# 74107        2.0         4                    1             1     3
# 74108        1.0         4                    1             1     4
# 74109        1.0         4                    2             1     4
# 74110        1.0         4                    1             0     3
#
#        description  first_review  host_has_profile_pic  \
# 0             9972          2079                     1
# 1            19019          2492                     1
# 2            55642          2395                     1
# 3            63089          2395                     1
# 4            15914          1676                     1
# ...            ...           ...                   ...
# 74106        72523          1994                     1
# 74107        30741          2137                     1
# 74108         4691          1547                     1
# 74109        21026          1547                     1
# 74110        71303          1064                     1
#
#        host_identity_verified  host_response_rate  host_since  \
# 0                           1                  80        1069
# 1                           0                   2        2980
# 2                           1                   2        2743
# 3                           1                  80        2188
# 4                           1                   2        2139
# ...                       ...                 ...         ...
# 74106                       1                  80        1432
# 74107                       0                   2        2568
# 74108                       1                   2         988
# 74109                       0                   2        3070
# 74110                       1                   2        1314
#
#        instant_bookable  last_review   latitude   longitude   name  \
# 0                     0          926  40.696524  -73.991617  10464
# 1                     1         1358  40.766115  -73.989040  65672
# 2                     1         1349  40.808110  -73.943756  66396
# 3                     0         1349  37.772004 -122.431619   9387
# 4                     1         1114  38.925627  -77.034596  32068
# ...                 ...          ...        ...         ...    ...
# 74106                 0         1142  40.709025  -73.939405  72348
# 74107                 0         1197  33.871549 -118.396053  59902
# 74108                 1         1345  40.706749  -73.942377  43692
# 74109                 1         1345  40.738535  -74.000157  26450
# 74110                 0         1212  33.761096 -118.192409  22195
#
#        neighbourhood  number_of_reviews  review_scores_rating  thumbnail_url  \
# 0                 77                  2                 100.0          32398
# 1                252                  6                  93.0          16220
# 2                247                 10                  92.0          32852
# 3                325                  0                   0.0          33692
# 4                119                  4                  40.0          65883
# ...              ...                ...                   ...            ...
# 74106            605                  0                   0.0          25229
# 74107            255                 16                  93.0          13695
# 74108            605                 43                  94.0          37484
# 74109            592                  0                   0.0          51019
# 74110            319                205                  96.0          10902
#
#        zipcode  bedrooms  beds
# 0          195       1.0   1.0
# 1           74       3.0   3.0
# 2           84       1.0   3.0
# 3          748       2.0   2.0
# 4          341       0.0   1.0
# ...        ...       ...   ...
# 74106      203       1.0   1.0
# 74107      515       2.0   4.0
# 74108      203       2.0   2.0
# 74109       61       0.0   2.0
# 74110      577       1.0   2.0
#
# [74111 rows x 29 columns]

# %% [markdown]
# # HeatMap

# %%
plt.figure(figsize = (40,40))
sns.heatmap(df.corr(), annot=True, fmt=".2f", cmap="seismic")
plt.show()

# %%
x = df.drop(["id","name","log_price","description","first_review","host_since","last_review","neighbourhood",
            "thumbnail_url", "zipcode"],axis = 1)
y = df.log_price

# %%
x
# Out:
#        property_type  room_type  amenities  accommodates  bathrooms  bed_type  \
# 0                  0          0        152             3        1.0         4
# 1                  0          0        218             7        1.0         4
# 2                  0          0        311             5        1.0         4
# 3                 17          0        210             4        1.0         4
# 4                  0          0        174             2        1.0         4
# ...              ...        ...        ...           ...        ...       ...
# 74106              0          1          2             1        1.0         4
# 74107              0          0        224             4        2.0         4
# 74108              0          0        402             5        1.0         4
# 74109              0          0        189             2        1.0         4
# 74110              2          0        279             4        1.0         4
#
#        cancellation_policy  cleaning_fee  city  host_has_profile_pic  \
# 0                        2             1     4                     1
# 1                        2             1     4                     1
# 2                        1             1     4                     1
# 3                        0             1     5                     1
# 4                        1             1     2                     1
# ...                    ...           ...   ...                   ...
# 74106                    0             0     4                     1
# 74107                    1             1     3                     1
# 74108                    1             1     4                     1
# 74109                    2             1     4                     1
# 74110                    1             0     3                     1
#
#        host_identity_verified  host_response_rate  instant_bookable  \
# 0                           1                  80                 0
# 1                           0                   2                 1
# 2                           1                   2                 1
# 3                           1                  80                 0
# 4                           1                   2                 1
# ...                       ...                 ...               ...
# 74106                       1                  80                 0
# 74107                       0                   2                 0
# 74108                       1                   2                 1
# 74109                       0                   2                 1
# 74110                       1                   2                 0
#
#         latitude   longitude  number_of_reviews  review_scores_rating  \
# 0      40.696524  -73.991617                  2                 100.0
# 1      40.766115  -73.989040                  6                  93.0
# 2      40.808110  -73.943756                 10                  92.0
# 3      37.772004 -122.431619                  0                   0.0
# 4      38.925627  -77.034596                  4                  40.0
# ...          ...         ...                ...                   ...
# 74106  40.709025  -73.939405                  0                   0.0
# 74107  33.871549 -118.396053                 16                  93.0
# 74108  40.706749  -73.942377                 43                  94.0
# 74109  40.738535  -74.000157                  0                   0.0
# 74110  33.761096 -118.192409                205                  96.0
#
#        bedrooms  beds
# 0           1.0   1.0
# 1           3.0   3.0
# 2           1.0   3.0
# 3           2.0   2.0
# 4           0.0   1.0
# ...         ...   ...
# 74106       1.0   1.0
# 74107       2.0   4.0
# 74108       2.0   2.0
# 74109       0.0   2.0
# 74110       1.0   2.0
#
# [74111 rows x 19 columns]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=101)

# %% [markdown]
# ## Model Building

# %% [markdown]
# # Linear Regression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)

y_pred_lr = lr.predict(x_test)

# %%
mae_lr = metrics.mean_absolute_error(y_test, y_pred_lr)
mse_lr = metrics.mean_squared_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(metrics.mean_squared_error(y_test, y_pred_lr))
r2_lr = metrics.r2_score(y_test, y_pred_lr)


print('\nMean Absolute Error of Linear Regression     : ', mae_lr)
print('\nMean Squarred Error of Linear Regression     : ', mse_lr)
print('\nRoot Mean Squarred Error of Linear Regression: ', rmse_lr)
print('\nR2 Score of Linear Regression                : ', r2_lr)
# Out:
# Mean Absolute Error of Linear Regression     :  0.36870444242179223
#
# Mean Squarred Error of Linear Regression     :  0.23465903965420423
#
# Root Mean Squarred Error of Linear Regression:  0.48441618434379774
#
# R2 Score of Linear Regression                :  0.546881442650814

# %% [markdown]
# # Random Forest

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x_train,y_train)

y_pred_rf = rf.predict(x_test)

# %%
mae_rf = metrics.mean_absolute_error(y_test, y_pred_rf)
mse_rf = metrics.mean_squared_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(metrics.mean_squared_error(y_test, y_pred_rf))
r2_rf = metrics.r2_score(y_test, y_pred_rf)


print('\nMean Absolute Error of Random Forest Regressor     : ', mae_rf)
print('\nMean Squarred Error of Random Forest Regressor     : ', mse_rf)
print('\nRoot Mean Squarred Error of Random Forest Regressor: ', rmse_rf)
print('\nR2 Score of Random Forest Regressor                : ', r2_rf)
# Out:
# Mean Absolute Error of Random Forest Regressor     :  0.2832446599806008
#
# Mean Squarred Error of Random Forest Regressor     :  0.15475870754800392
#
# Root Mean Squarred Error of Random Forest Regressor:  0.3933938326257847
#
# R2 Score of Random Forest Regressor                :  0.7011662435646562

# %% [markdown]
# # Polynomial Regression

# %%
from sklearn.linear_model import Ridge
model = Pipeline([
    ('poly', PolynomialFeatures()),
    ('ridge', Ridge(fit_intercept=True))
])

param_grid = {
    'poly__degree': [1, 2, 3],
    'ridge__alpha': [0.1, 0.5, 1.0, 2.0]
}

# Perform grid search with 5-fold cross-validation

poly_tuned = GridSearchCV(model, param_grid, cv=5)

# %%
#Traning and Testing

poly_tuned.fit(x_train, y_train)

y_pred_poly = poly_tuned.predict(x_test)

# %%
mae_poly  = metrics.mean_absolute_error(y_test, y_pred_poly)
mse_poly  = metrics.mean_squared_error(y_test, y_pred_poly)
rmse_poly = np.sqrt(metrics.mean_squared_error(y_test, y_pred_poly))
r2_poly   = metrics.r2_score(y_test, y_pred_poly)


print('\nMean Absolute Error of Polynomial Regression     : ', mae_poly)
print('\nMean Squarred Error of Polynomial Regression     : ', mse_poly)
print('\nRoot Mean Squarred Error of Polynomial Regression: ', rmse_poly)
print('\nR2 Score of Polynomial Regression                : ', r2_poly)
# Out:
# Mean Absolute Error of Polynomial Regression     :  0.3423229567210498
#
# Mean Squarred Error of Polynomial Regression     :  0.2038505051500706
#
# Root Mean Squarred Error of Polynomial Regression:  0.4514980677146588
#
# R2 Score of Polynomial Regression                :  0.6063716661219707

# %% [markdown]
# # CatBoost

# %%
model_CBR = CatBoostRegressor()

# %%
model_CBR.fit(x_train, y_train)

cross_val_score(model_CBR, x_train, y_train,
                           scoring='r2',
                           cv=KFold(n_splits=5,
                                    shuffle=True,
                                    random_state=2022,
                                    ))
# Out:
# Learning rate set to 0.078038
# 0:	learn: 0.6884814	total: 61.5ms	remaining: 1m 1s
# 1:	learn: 0.6629188	total: 64.6ms	remaining: 32.2s
# 2:	learn: 0.6397968	total: 67.7ms	remaining: 22.5s
# 3:	learn: 0.6197053	total: 70.5ms	remaining: 17.5s
# 4:	learn: 0.6022100	total: 73.4ms	remaining: 14.6s
# 5:	learn: 0.5867609	total: 76.5ms	remaining: 12.7s
# 6:	learn: 0.5716923	total: 79.3ms	remaining: 11.2s
# 7:	learn: 0.5592553	total: 82ms	remaining: 10.2s
# 8:	learn: 0.5475392	total: 84.9ms	remaining: 9.35s
# 9:	learn: 0.5373710	total: 87.9ms	remaining: 8.7s
# 10:	learn: 0.5274211	total: 90.7ms	remaining: 8.15s
# 11:	learn: 0.5182308	total: 93.7ms	remaining: 7.72s
# 12:	learn: 0.5107779	total: 96.6ms	remaining: 7.33s
# 13:	learn: 0.5038525	total: 99.6ms	remaining: 7.01s
# 14:	learn: 0.4975683	total: 102ms	remaining: 6.71s
# 15:	learn: 0.4914023	total: 105ms	remaining: 6.47s
# 16:	learn: 0.4865003	total: 108ms	remaining: 6.25s
# 17:	learn: 0.4820088	total: 111ms	remaining: 6.05s
# 18:	learn: 0.4773001	total: 114ms	remaining: 5.86s
# 19:	learn: 0.4738851	total: 116ms	remaining: 5.7s
# 352:	learn: 0.3784661	total: 1.11s	remaining: 2.04s
# 353:	learn: 0.3784202	total: 1.11s	remaining: 2.03s
# 354:	learn: 0.3783911	total: 1.12s	remaining: 2.03s
# 355:	learn: 0.3783631	total: 1.12s	remaining: 2.03s
# 356:	learn: 0.3783022	total: 1.12s	remaining: 2.02s
# 357:	learn: 0.3782447	total: 1.13s	remaining: 2.02s
# 358:	learn: 0.3781964	total: 1.13s	remaining: 2.02s
# 359:	learn: 0.3781424	total: 1.13s	remaining: 2.02s
# 360:	learn: 0.3780781	total: 1.14s	remaining: 2.01s
# 361:	learn: 0.3779856	total: 1.14s	remaining: 2.01s
# 362:	learn: 0.3779236	total: 1.14s	remaining: 2.01s
# 363:	learn: 0.3778533	total: 1.15s	remaining: 2s
# 364:	learn: 0.3778162	total: 1.15s	remaining: 2s
# 365:	learn: 0.3777635	total: 1.15s	remaining: 2s
# 366:	learn: 0.3777393	total: 1.16s	remaining: 1.99s
# 367:	learn: 0.3776918	total: 1.16s	remaining: 1.99s
# 368:	learn: 0.3775804	total: 1.16s	remaining: 1.99s
# 369:	learn: 0.3775184	total: 1.16s	remaining: 1.98s
# 370:	learn: 0.3774636	total: 1.17s	remaining: 1.98s
# 371:	learn: 0.3774348	total: 1.17s	remaining: 1.98s
# 372:	learn: 0.3773733	total: 1.17s	remaining: 1.97s
# 373:	learn: 0.3773210	total: 1.18s	remaining: 1.97s
# 374:	learn: 0.3772669	total: 1.18s	remaining: 1.97s
# 375:	learn: 0.3772233	total: 1.18s	remaining: 1.97s
# 376:	learn: 0.3771739	total: 1.19s	remaining: 1.96s
# 377:	learn: 0.3770891	total: 1.19s	remaining: 1.96s
# 378:	learn: 0.3770304	total: 1.19s	remaining: 1.96s
# 379:	learn: 0.3769864	total: 1.2s	remaining: 1.95s
# 380:	learn: 0.3769437	total: 1.2s	remaining: 1.95s
# 381:	learn: 0.3768909	total: 1.2s	remaining: 1.95s
# 382:	learn: 0.3768204	total: 1.21s	remaining: 1.94s
# 383:	learn: 0.3767438	total: 1.21s	remaining: 1.94s
# 384:	learn: 0.3767135	total: 1.21s	remaining: 1.94s
# 385:	learn: 0.3766620	total: 1.21s	remaining: 1.93s
# 386:	learn: 0.3765942	total: 1.22s	remaining: 1.93s
# 387:	learn: 0.3765211	total: 1.22s	remaining: 1.92s
# 388:	learn: 0.3764686	total: 1.22s	remaining: 1.92s
# 389:	learn: 0.3764213	total: 1.23s	remaining: 1.92s
# 390:	learn: 0.3763841	total: 1.23s	remaining: 1.91s
# 391:	learn: 0.3763534	total: 1.23s	remaining: 1.91s
# 392:	learn: 0.3762826	total: 1.24s	remaining: 1.91s
# 393:	learn: 0.3762213	total: 1.24s	remaining: 1.91s
# 394:	learn: 0.3761705	total: 1.24s	remaining: 1.9s
# 395:	learn: 0.3761362	total: 1.24s	remaining: 1.9s
# 396:	learn: 0.3761015	total: 1.25s	remaining: 1.89s
# 397:	learn: 0.3760325	total: 1.25s	remaining: 1.89s
# 398:	learn: 0.3759877	total: 1.25s	remaining: 1.89s
# 399:	learn: 0.3759484	total: 1.25s	remaining: 1.88s
# 400:	learn: 0.3759183	total: 1.26s	remaining: 1.88s
# 401:	learn: 0.3758792	total: 1.26s	remaining: 1.88s
# 402:	learn: 0.3757791	total: 1.26s	remaining: 1.87s
# 403:	learn: 0.3757507	total: 1.27s	remaining: 1.87s
# 404:	learn: 0.3757138	total: 1.27s	remaining: 1.87s
# 405:	learn: 0.3756341	total: 1.27s	remaining: 1.86s
# 406:	learn: 0.3755833	total: 1.28s	remaining: 1.86s
# 407:	learn: 0.3755534	total: 1.28s	remaining: 1.86s
# 408:	learn: 0.3755135	total: 1.28s	remaining: 1.85s
# 409:	learn: 0.3754637	total: 1.28s	remaining: 1.85s
# 410:	learn: 0.3754033	total: 1.29s	remaining: 1.85s
# 411:	learn: 0.3753801	total: 1.29s	remaining: 1.84s
# 412:	learn: 0.3753405	total: 1.29s	remaining: 1.84s
# 413:	learn: 0.3752750	total: 1.3s	remaining: 1.84s
# 414:	learn: 0.3752416	total: 1.3s	remaining: 1.83s
# 415:	learn: 0.3752081	total: 1.3s	remaining: 1.83s
# 416:	learn: 0.3751408	total: 1.31s	remaining: 1.84s
# 417:	learn: 0.3750905	total: 1.32s	remaining: 1.84s
# 418:	learn: 0.3750356	total: 1.34s	remaining: 1.86s
# 419:	learn: 0.3749871	total: 1.35s	remaining: 1.87s
# 420:	learn: 0.3749557	total: 1.36s	remaining: 1.87s
# 421:	learn: 0.3748654	total: 1.36s	remaining: 1.87s
# 422:	learn: 0.3748330	total: 1.37s	remaining: 1.86s
# 423:	learn: 0.3748027	total: 1.37s	remaining: 1.86s
# 424:	learn: 0.3747372	total: 1.37s	remaining: 1.86s
# 425:	learn: 0.3747014	total: 1.38s	remaining: 1.86s
# 426:	learn: 0.3746370	total: 1.39s	remaining: 1.86s
# 427:	learn: 0.3745990	total: 1.39s	remaining: 1.86s
# 428:	learn: 0.3745633	total: 1.4s	remaining: 1.86s
# 429:	learn: 0.3745272	total: 1.4s	remaining: 1.86s
# 430:	learn: 0.3744988	total: 1.41s	remaining: 1.86s
# 431:	learn: 0.3744776	total: 1.42s	remaining: 1.86s
# 432:	learn: 0.3744222	total: 1.42s	remaining: 1.86s
# 433:	learn: 0.3743823	total: 1.43s	remaining: 1.86s
# 434:	learn: 0.3743548	total: 1.43s	remaining: 1.86s
# 435:	learn: 0.3743240	total: 1.43s	remaining: 1.85s
# 436:	learn: 0.3742605	total: 1.44s	remaining: 1.85s
# 437:	learn: 0.3741926	total: 1.44s	remaining: 1.85s
# 438:	learn: 0.3741542	total: 1.45s	remaining: 1.85s
# 439:	learn: 0.3740931	total: 1.45s	remaining: 1.85s
# 440:	learn: 0.3740597	total: 1.45s	remaining: 1.84s
# 441:	learn: 0.3740194	total: 1.46s	remaining: 1.84s
# 442:	learn: 0.3739780	total: 1.46s	remaining: 1.84s
# 443:	learn: 0.3739534	total: 1.47s	remaining: 1.84s
# 444:	learn: 0.3739198	total: 1.47s	remaining: 1.83s
# 491:	learn: 0.3717406	total: 1.66s	remaining: 1.71s
# 492:	learn: 0.3716990	total: 1.66s	remaining: 1.71s
# 493:	learn: 0.3716747	total: 1.67s	remaining: 1.71s
# 494:	learn: 0.3716238	total: 1.67s	remaining: 1.7s
# 495:	learn: 0.3715549	total: 1.67s	remaining: 1.7s
# 496:	learn: 0.3715228	total: 1.68s	remaining: 1.7s
# 497:	learn: 0.3714875	total: 1.68s	remaining: 1.69s
# 498:	learn: 0.3714302	total: 1.68s	remaining: 1.69s
# 499:	learn: 0.3713735	total: 1.69s	remaining: 1.69s
# 500:	learn: 0.3713372	total: 1.69s	remaining: 1.68s
# 501:	learn: 0.3713051	total: 1.69s	remaining: 1.68s
# 502:	learn: 0.3712645	total: 1.69s	remaining: 1.67s
# 503:	learn: 0.3712191	total: 1.7s	remaining: 1.67s
# 504:	learn: 0.3711881	total: 1.7s	remaining: 1.67s
# 505:	learn: 0.3710933	total: 1.7s	remaining: 1.66s
# 506:	learn: 0.3710412	total: 1.71s	remaining: 1.66s
# 507:	learn: 0.3710121	total: 1.71s	remaining: 1.66s
# 508:	learn: 0.3709863	total: 1.71s	remaining: 1.65s
# 509:	learn: 0.3709292	total: 1.72s	remaining: 1.65s
# 510:	learn: 0.3708945	total: 1.72s	remaining: 1.65s
# 511:	learn: 0.3708428	total: 1.72s	remaining: 1.64s
# 512:	learn: 0.3707931	total: 1.73s	remaining: 1.64s
# 513:	learn: 0.3707817	total: 1.73s	remaining: 1.64s
# 514:	learn: 0.3707577	total: 1.73s	remaining: 1.63s
# 515:	learn: 0.3707320	total: 1.74s	remaining: 1.63s
# 516:	learn: 0.3706840	total: 1.74s	remaining: 1.62s
# 517:	learn: 0.3706546	total: 1.74s	remaining: 1.62s
# 518:	learn: 0.3706267	total: 1.74s	remaining: 1.62s
# 519:	learn: 0.3705884	total: 1.75s	remaining: 1.61s
# 520:	learn: 0.3705528	total: 1.75s	remaining: 1.61s
# 521:	learn: 0.3705334	total: 1.75s	remaining: 1.6s
# 522:	learn: 0.3705124	total: 1.75s	remaining: 1.6s
# 523:	learn: 0.3704923	total: 1.76s	remaining: 1.6s
# 524:	learn: 0.3704365	total: 1.76s	remaining: 1.59s
# 525:	learn: 0.3703846	total: 1.76s	remaining: 1.59s
# 526:	learn: 0.3703532	total: 1.77s	remaining: 1.59s
# 527:	learn: 0.3703226	total: 1.77s	remaining: 1.58s
# 528:	learn: 0.3702981	total: 1.77s	remaining: 1.58s
# 529:	learn: 0.3702505	total: 1.78s	remaining: 1.57s
# 530:	learn: 0.3702113	total: 1.78s	remaining: 1.57s
# 531:	learn: 0.3701694	total: 1.78s	remaining: 1.57s
# 532:	learn: 0.3701327	total: 1.78s	remaining: 1.56s
# 533:	learn: 0.3700815	total: 1.79s	remaining: 1.56s
# 534:	learn: 0.3699945	total: 1.79s	remaining: 1.56s
# 535:	learn: 0.3699650	total: 1.79s	remaining: 1.55s
# 536:	learn: 0.3699230	total: 1.8s	remaining: 1.55s
# 583:	learn: 0.3682282	total: 1.94s	remaining: 1.38s
# 584:	learn: 0.3681916	total: 1.94s	remaining: 1.37s
# 585:	learn: 0.3681552	total: 1.94s	remaining: 1.37s
# 586:	learn: 0.3681233	total: 1.94s	remaining: 1.37s
# 587:	learn: 0.3680918	total: 1.95s	remaining: 1.36s
# 588:	learn: 0.3680618	total: 1.95s	remaining: 1.36s
# 589:	learn: 0.3680066	total: 1.95s	remaining: 1.36s
# 590:	learn: 0.3679837	total: 1.96s	remaining: 1.35s
# 591:	learn: 0.3679255	total: 1.96s	remaining: 1.35s
# 592:	learn: 0.3679086	total: 1.96s	remaining: 1.35s
# 593:	learn: 0.3678737	total: 1.97s	remaining: 1.34s
# 594:	learn: 0.3678181	total: 1.97s	remaining: 1.34s
# 595:	learn: 0.3677912	total: 1.97s	remaining: 1.34s
# 596:	learn: 0.3677667	total: 1.97s	remaining: 1.33s
# 597:	learn: 0.3677292	total: 1.98s	remaining: 1.33s
# 598:	learn: 0.3677023	total: 1.98s	remaining: 1.32s
# 599:	learn: 0.3676452	total: 1.98s	remaining: 1.32s
# 600:	learn: 0.3676097	total: 1.99s	remaining: 1.32s
# 601:	learn: 0.3675750	total: 1.99s	remaining: 1.31s
# 602:	learn: 0.3675441	total: 1.99s	remaining: 1.31s
# 603:	learn: 0.3675040	total: 2s	remaining: 1.31s
# 604:	learn: 0.3674798	total: 2s	remaining: 1.3s
# 605:	learn: 0.3674495	total: 2s	remaining: 1.3s
# 606:	learn: 0.3674287	total: 2s	remaining: 1.3s
# 607:	learn: 0.3673762	total: 2.01s	remaining: 1.29s
# 608:	learn: 0.3673701	total: 2.01s	remaining: 1.29s
# 609:	learn: 0.3673430	total: 2.01s	remaining: 1.29s
# 610:	learn: 0.3672952	total: 2.02s	remaining: 1.28s
# 611:	learn: 0.3672428	total: 2.02s	remaining: 1.28s
# 612:	learn: 0.3672057	total: 2.02s	remaining: 1.27s
# 613:	learn: 0.3671780	total: 2.02s	remaining: 1.27s
# 614:	learn: 0.3671517	total: 2.03s	remaining: 1.27s
# 615:	learn: 0.3670848	total: 2.03s	remaining: 1.26s
# 616:	learn: 0.3670706	total: 2.03s	remaining: 1.26s
# 617:	learn: 0.3670472	total: 2.03s	remaining: 1.26s
# 618:	learn: 0.3670118	total: 2.04s	remaining: 1.25s
# 619:	learn: 0.3669893	total: 2.04s	remaining: 1.25s
# 620:	learn: 0.3669398	total: 2.04s	remaining: 1.25s
# 621:	learn: 0.3669079	total: 2.05s	remaining: 1.24s
# 622:	learn: 0.3668904	total: 2.05s	remaining: 1.24s
# 623:	learn: 0.3668652	total: 2.05s	remaining: 1.24s
# 624:	learn: 0.3668323	total: 2.06s	remaining: 1.23s
# 625:	learn: 0.3667758	total: 2.06s	remaining: 1.23s
# 626:	learn: 0.3667608	total: 2.06s	remaining: 1.23s
# 627:	learn: 0.3667158	total: 2.06s	remaining: 1.22s
# 628:	learn: 0.3666936	total: 2.07s	remaining: 1.22s
# 629:	learn: 0.3666718	total: 2.07s	remaining: 1.22s
# 630:	learn: 0.3666449	total: 2.07s	remaining: 1.21s
# 631:	learn: 0.3665969	total: 2.08s	remaining: 1.21s
# 632:	learn: 0.3665543	total: 2.08s	remaining: 1.2s
# 633:	learn: 0.3665247	total: 2.08s	remaining: 1.2s
# 634:	learn: 0.3664948	total: 2.08s	remaining: 1.2s
# 635:	learn: 0.3664535	total: 2.09s	remaining: 1.19s
# 636:	learn: 0.3664356	total: 2.09s	remaining: 1.19s
# 637:	learn: 0.3664077	total: 2.09s	remaining: 1.19s
# 638:	learn: 0.3663856	total: 2.09s	remaining: 1.18s
# 639:	learn: 0.3663412	total: 2.1s	remaining: 1.18s
# 640:	learn: 0.3663039	total: 2.1s	remaining: 1.18s
# 641:	learn: 0.3662728	total: 2.1s	remaining: 1.17s
# 642:	learn: 0.3662451	total: 2.11s	remaining: 1.17s
# 643:	learn: 0.3662027	total: 2.11s	remaining: 1.17s
# 644:	learn: 0.3661751	total: 2.11s	remaining: 1.16s
# 645:	learn: 0.3661527	total: 2.12s	remaining: 1.16s
# 646:	learn: 0.3661301	total: 2.12s	remaining: 1.16s
# 647:	learn: 0.3660717	total: 2.12s	remaining: 1.15s
# 648:	learn: 0.3660439	total: 2.12s	remaining: 1.15s
# 649:	learn: 0.3660032	total: 2.13s	remaining: 1.15s
# 650:	learn: 0.3659591	total: 2.13s	remaining: 1.14s
# 651:	learn: 0.3659171	total: 2.13s	remaining: 1.14s
# 652:	learn: 0.3658872	total: 2.14s	remaining: 1.14s
# 653:	learn: 0.3658645	total: 2.14s	remaining: 1.13s
# 654:	learn: 0.3658281	total: 2.14s	remaining: 1.13s
# 655:	learn: 0.3657708	total: 2.15s	remaining: 1.13s
# 656:	learn: 0.3657346	total: 2.15s	remaining: 1.12s
# 657:	learn: 0.3657115	total: 2.15s	remaining: 1.12s
# 658:	learn: 0.3656619	total: 2.15s	remaining: 1.11s
# 659:	learn: 0.3656256	total: 2.16s	remaining: 1.11s
# 660:	learn: 0.3655937	total: 2.16s	remaining: 1.11s
# 661:	learn: 0.3655719	total: 2.16s	remaining: 1.1s
# 662:	learn: 0.3655515	total: 2.17s	remaining: 1.1s
# 663:	learn: 0.3655018	total: 2.17s	remaining: 1.1s
# 664:	learn: 0.3654705	total: 2.17s	remaining: 1.09s
# 665:	learn: 0.3654533	total: 2.18s	remaining: 1.09s
# 666:	learn: 0.3654261	total: 2.18s	remaining: 1.09s
# 667:	learn: 0.3654062	total: 2.18s	remaining: 1.08s
# 668:	learn: 0.3653723	total: 2.18s	remaining: 1.08s
# 669:	learn: 0.3653522	total: 2.19s	remaining: 1.08s
# 670:	learn: 0.3653313	total: 2.19s	remaining: 1.07s
# 671:	learn: 0.3652851	total: 2.19s	remaining: 1.07s
# 672:	learn: 0.3652557	total: 2.19s	remaining: 1.07s
# 673:	learn: 0.3652235	total: 2.2s	remaining: 1.06s
# 674:	learn: 0.3651990	total: 2.2s	remaining: 1.06s
# 961:	learn: 0.3568695	total: 3.11s	remaining: 123ms
# 962:	learn: 0.3568278	total: 3.11s	remaining: 120ms
# 963:	learn: 0.3568104	total: 3.11s	remaining: 116ms
# 964:	learn: 0.3567713	total: 3.12s	remaining: 113ms
# 965:	learn: 0.3567477	total: 3.12s	remaining: 110ms
# 966:	learn: 0.3567194	total: 3.12s	remaining: 107ms
# 967:	learn: 0.3566945	total: 3.12s	remaining: 103ms
# 968:	learn: 0.3566611	total: 3.13s	remaining: 100ms
# 969:	learn: 0.3566410	total: 3.13s	remaining: 96.8ms
# 970:	learn: 0.3566243	total: 3.13s	remaining: 93.6ms
# 971:	learn: 0.3565991	total: 3.13s	remaining: 90.3ms
# 972:	learn: 0.3565668	total: 3.14s	remaining: 87.1ms
# 973:	learn: 0.3565360	total: 3.14s	remaining: 83.8ms
# 974:	learn: 0.3565112	total: 3.14s	remaining: 80.6ms
# 975:	learn: 0.3564822	total: 3.15s	remaining: 77.4ms
# 976:	learn: 0.3564551	total: 3.15s	remaining: 74.1ms
# 977:	learn: 0.3564412	total: 3.15s	remaining: 70.9ms
# 978:	learn: 0.3564041	total: 3.15s	remaining: 67.7ms
# 979:	learn: 0.3563910	total: 3.16s	remaining: 64.5ms
# 980:	learn: 0.3563688	total: 3.16s	remaining: 61.2ms
# 981:	learn: 0.3563320	total: 3.16s	remaining: 58ms
# 982:	learn: 0.3563067	total: 3.17s	remaining: 54.8ms
# 983:	learn: 0.3562841	total: 3.17s	remaining: 51.5ms
# 984:	learn: 0.3562564	total: 3.17s	remaining: 48.3ms
# 985:	learn: 0.3562243	total: 3.17s	remaining: 45.1ms
# 986:	learn: 0.3561944	total: 3.18s	remaining: 41.9ms
# 987:	learn: 0.3561528	total: 3.18s	remaining: 38.6ms
# 988:	learn: 0.3561405	total: 3.18s	remaining: 35.4ms
# 989:	learn: 0.3561308	total: 3.19s	remaining: 32.2ms
# 990:	learn: 0.3561262	total: 3.19s	remaining: 29ms
# 991:	learn: 0.3560843	total: 3.19s	remaining: 25.7ms
# 992:	learn: 0.3560650	total: 3.19s	remaining: 22.5ms
# 993:	learn: 0.3560419	total: 3.2s	remaining: 19.3ms
# 994:	learn: 0.3560178	total: 3.2s	remaining: 16.1ms
# 995:	learn: 0.3559824	total: 3.2s	remaining: 12.9ms
# 996:	learn: 0.3559500	total: 3.21s	remaining: 9.65ms
# 997:	learn: 0.3559318	total: 3.21s	remaining: 6.43ms
# 998:	learn: 0.3559134	total: 3.21s	remaining: 3.21ms
# 999:	learn: 0.3558711	total: 3.21s	remaining: 0us
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages/sklearn/utils/_tags.py:275, in get_tags(estimator)
#     274 try:
# --> 275     tags = estimator.__sklearn_tags__()
#     276 except AttributeError as exc:
#
# AttributeError: 'CatBoostRegressor' object has no attribute '__sklearn_tags__'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In[83], line 3
#       1 model_CBR.fit(x_train, y_train)
# ----> 3 cross_val_score(model_CBR, x_train, y_train,
#       4                            scoring='r2',
#       5                            cv=KFold(n_splits=5,
#       6                                     shuffle=True,
#       7                                     random_state=2022,
#       8                                     ))
#
# File ~/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:651, in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, error_score)
#     648 # To ensure multimetric format is not supported
#     649 scorer = check_scoring(estimator, scoring=scoring)
# --> 651 cv_results = cross_validate(
#     652     estimator=estimator,
#     653     X=X,
#     654     y=y,
#     655     groups=groups,
#     656     scoring={"score": scorer},
#     657     cv=cv,
#     658     n_jobs=n_jobs,
#     659     verbose=verbose,
#     660     params=params,
#     661     pre_dispatch=pre_dispatch,
#     662     error_score=error_score,
#     663 )
#     664 return cv_results["test_score"]
#
# File ~/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:320, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     318 X, y = indexable(X, y)
#     319 params = {} if params is None else params
# --> 320 cv = check_cv(cv, y, classifier=is_classifier(estimator))
#     322 scorers = check_scoring(
#     323     estimator, scoring=scoring, raise_exc=(error_score == "raise")
#     324 )
#     326 if _routing_enabled():
#     327     # For estimators, a MetadataRouter is created in get_metadata_routing
#     328     # methods. For these router methods, we create the router to use
#     329     # `process_routing` on it.
#
# File ~/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages/sklearn/base.py:1211, in is_classifier(estimator)
#    1183 def is_classifier(estimator):
#    1184     """Return True if the given estimator is (probably) a classifier.
#    1185
#    1186     Parameters
#    (...)   1209     False
#    1210     """
# -> 1211     return get_tags(estimator).estimator_type == "classifier"
#
# File ~/Projects/End-to-End-Airbnb-Price-Prediction/venv/lib/python3.11/site-packages/sklearn/utils/_tags.py:283, in get_tags(estimator)
#     276 except AttributeError as exc:
#     277     if "object has no attribute '__sklearn_tags__'" in str(exc):
#     278         # Happens when `__sklearn_tags__` is implemented by calling
#     279         # `super().__sklearn_tags__()` but there is no `__sklearn_tags__`
#     280         # method in the base class. Typically happens when only inheriting
#     281         # from Mixins.
# --> 283         raise AttributeError(
#     284             f"The following error was raised: {exc}. It seems that "
#     285             "there are no classes that implement `__sklearn_tags__` "
#     286             "in the MRO and/or all classes in the MRO call "
#     287             "`super().__sklearn_tags__()`. Make sure to inherit from "
#     288             "`BaseEstimator` which implements `__sklearn_tags__` (or "
#     289             "alternatively define `__sklearn_tags__` but we don't recommend "
#     290             "this approach). Note that `BaseEstimator` needs to be on the "
#     291             "right side of other Mixins in the inheritance order."
#     292         )
#     293     else:
#     294         raise
#
# AttributeError: The following error was raised: 'CatBoostRegressor' object has no attribute '__sklearn_tags__'. It seems that there are no classes that implement `__sklearn_tags__` in the MRO and/or all classes in the MRO call `super().__sklearn_tags__()`. Make sure to inherit from `BaseEstimator` which implements `__sklearn_tags__` (or alternatively define `__sklearn_tags__` but we don't recommend this approach). Note that `BaseEstimator` needs to be on the right side of other Mixins in the inheritance order.

# %%
y_pred_cbr = model_CBR.predict(x_test)

# %%
mae_cbr  = metrics.mean_absolute_error(y_test, y_pred_cbr)
mse_cbr  = metrics.mean_squared_error(y_test, y_pred_cbr)
rmse_cbr = np.sqrt(metrics.mean_squared_error(y_test, y_pred_cbr))
r2_cbr   = metrics.r2_score(y_test, y_pred_cbr)


print('\nMean Absolute Error of CatBoost Regressor     : ', mae_cbr)
print('\nMean Squarred Error of CatBoost Regressor     : ', mse_cbr)
print('\nRoot Mean Squarred Error of CatBoost Regressor: ', rmse_cbr)
print('\nR2 Score of CatBoost Regressor                : ', r2_cbr)

# %% [markdown]
# # Gradient Boosting

# %%
gb = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=3)

# %%
gb.fit(x_train, y_train)

y_pred_gb = gb.predict(x_test)

# %%
mae_gb  = metrics.mean_absolute_error(y_test, y_pred_gb)
mse_gb  = metrics.mean_squared_error(y_test, y_pred_gb)
rmse_gb = np.sqrt(metrics.mean_squared_error(y_test, y_pred_gb))
r2_gb   = metrics.r2_score(y_test, y_pred_gb)


print('\nMean Absolute Error of Gradient Boosting     : ', mae_gb)
print('\nMean Squarred Error of Gradient Boosting     : ', mse_gb)
print('\nRoot Mean Squarred Error of Gradient Boosting: ', rmse_gb)
print('\nR2 Score of Gradient Boosting                : ', r2_gb)

# %% [markdown]
# # XGBoost

# %%
xgb = XGBRegressor(objective='reg:squarederror')

# %%
xgb.fit(x_train, y_train)

# %%
y_pred_xgb = xgb.predict(x_test)

# %%
mae_xgb  = metrics.mean_absolute_error(y_test, y_pred_xgb)
mse_xgb  = metrics.mean_squared_error(y_test, y_pred_xgb)
rmse_xgb = np.sqrt(metrics.mean_squared_error(y_test, y_pred_xgb))
r2_xgb   = metrics.r2_score(y_test, y_pred_xgb)


print('\nMean Absolute Error of XGBoost Regressor     : ', mae_xgb)
print('\nMean Squarred Error of XGBoost Regressor     : ', mse_xgb)
print('\nRoot Mean Squarred Error of XGBoost Regressor: ', rmse_xgb)
print('\nR2 Score of XGBoost Regressor                : ', r2_xgb)

# %%
r2_list = {"Linear Regression": r2_lr,
          "Random Forest": r2_rf ,
          "Polynomial Regression": r2_poly,
          "CatBoost": r2_cbr,
          "Gradient Boosting":r2_gb ,
          "XGBoost": r2_xgb}

mae_list = {"Linear Regression": mae_lr,
          "Random Forest": mae_rf ,
          "Polynomial Regression": mae_poly,
          "CatBoost": mae_cbr,
          "Gradient Boosting":mae_gb ,
          "XGBoost": mae_xgb}

mse_list = {"Linear Regression": mse_lr,
          "Random Forest": mse_rf ,
          "Polynomial Regression": mse_poly,
          "CatBoost": mse_cbr,
          "Gradient Boosting":mse_gb ,
          "XGBoost": mse_xgb}

rmse_list = {"Linear Regression": rmse_lr,
          "Random Forest": rmse_rf ,
          "Polynomial Regression": rmse_poly,
          "CatBoost": rmse_cbr,
          "Gradient Boosting":rmse_gb ,
          "XGBoost": rmse_xgb}

# %%
a1 =  pd.DataFrame.from_dict(r2_list, orient = 'index', columns = ["R2 SCORE"])
a2 =  pd.DataFrame.from_dict(mae_list, orient = 'index', columns = ["MEAN ABSOLUTE ERROR"])
a3 =  pd.DataFrame.from_dict(mse_list, orient = 'index', columns = ["MEAN SQUARRED ERROR"])
a4 =  pd.DataFrame.from_dict(rmse_list, orient = 'index', columns = ["ROOT MEAN SQUARRED ERROR"])

# %%
org = pd.concat([a1, a2, a3, a4], axis = 1)
org

# %%
alg = ['LR','RF','PR','CBR','GB','XGB']
plt.plot(alg,a1)
plt.plot(alg,a2)
plt.plot(alg,a3)
plt.plot(alg,a4)
legend = ["R2 SCORE", "MEAN ABSOLUTE ERROR", "MEAN SQUARRED ERROR", "ROOT MEAN SQUARRED ERROR"]

plt.title("METRICS COMPARISION")
plt.legend(legend, loc= 'right', fontsize='xx-small')
plt.show()

# %%
import pickle
pickle.dump(model_CBR, open("catboostalgo.pkl", "wb"))

# %% [markdown]
# # Model Monitoring

# %%
try:
    import evidently
except:
    # !pip install git+https://github.com/evidentlyai/evidently.git

# %%
import pandas as pd
import numpy as np
import requests
import io

from evidently import ColumnMapping
from evidently.report import Report
from evidently.metric_preset import DataDriftPreset, TargetDriftPreset, RegressionPreset

# %%
target = 'log_price'
prediction = 'prediction'
numerical_features = numerical_col
categorical_features = categorical_col

# %%
reference = df.loc[:25000]

current = df.loc[25000:]

# %%
regressor = model_CBR

# %%
regressor.fit(reference[numerical_features+categorical_features],reference[target])

# %%
ref_prediction = regressor.predict(reference[numerical_features+categorical_features])

current_prediction = regressor.predict(current[numerical_features+categorical_features])

# %%
reference['prediction'] = ref_prediction

current['prediction'] = current_prediction

# %%
column_mapping = ColumnMapping()

column_mapping.target = target
column_mapping.prediction = prediction
column_mapping.numerical_features = numerical_features
column_mapping.categorical_features = categorical_features

# %%
regression_perfomance = Report(metrics=[RegressionPreset()])
regression_perfomance.run(current_data=reference, reference_data=None, column_mapping=column_mapping)

# %%
regression_perfomance.show()
